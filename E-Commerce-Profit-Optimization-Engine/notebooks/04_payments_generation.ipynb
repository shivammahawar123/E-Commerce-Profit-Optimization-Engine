# %%
import pandas as pd
import random
from faker import Faker

# %%
fake = Faker()

# %%
orders_df = pd.read_csv(
    "../data/orders.csv"
)

# %%
payments = []

# %%
payment_methods = [
    "Credit Card",
    "Debit Card",
    "PayPal",
    "Apple Pay",
    "Cash on Delivery"
]

payment_statuses = [
    "Completed",
    "Pending",
    "Failed"
]

for i in range(len(orders_df)):

    order = orders_df.iloc[i]

    payments.append({
        "payment_id": i + 1,
        "order_id": order["order_id"],
        "payment_method": random.choice(payment_methods),
        "payment_status": random.choice(payment_statuses),
        "payment_date": order["order_date"]
    })

# %%
payments_df = pd.DataFrame(payments)

# %%
payments_df.head()
# Out:
#    payment_id  order_id payment_method payment_status payment_date
# 0           1         1     Debit Card      Completed   2026-01-01
# 1           2         2      Apple Pay         Failed   2025-10-03
# 2           3         3    Credit Card      Completed   2025-02-20
# 3           4         4    Credit Card      Completed   2025-03-02
# 4           5         5    Credit Card      Completed   2025-09-04

# %%
payments_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   payment_id      50000 non-null  int64
#  1   order_id        50000 non-null  int64
#  2   payment_method  50000 non-null  str
#  3   payment_status  50000 non-null  str
#  4   payment_date    50000 non-null  str
# dtypes: int64(2), str(3)
# memory usage: 1.9 MB

# %%
payments_df.isnull().sum()
# Out:
# payment_id        0
# order_id          0
# payment_method    0
# payment_status    0
# payment_date      0
# dtype: int64

# %%
payments_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
payments_df["payment_date"] = pd.to_datetime(
    payments_df["payment_date"]
)

# %%
payments_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   payment_id      50000 non-null  int64
#  1   order_id        50000 non-null  int64
#  2   payment_method  50000 non-null  str
#  3   payment_status  50000 non-null  str
#  4   payment_date    50000 non-null  datetime64[us]
# dtypes: datetime64[us](1), int64(2), str(2)
# memory usage: 1.9 MB

# %%
payments_df.to_csv(
    "../data/payments.csv",
    index=False
)
